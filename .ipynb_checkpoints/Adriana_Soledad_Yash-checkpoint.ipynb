# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt 


from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder

# %%
# 1. Load raw CSVs
df1 = pd.read_csv('CIS62.20250516213458.csv')  # IP engagement rates 
df2 = pd.read_csv('BSA02.20250516T100541.csv')  # Total R&D expenditure 
df3 = pd.read_csv('BSA22.20250516T200531.csv')  # R&D enterprise headcounts

# %%
# Display head and info for df1
print("="*50)
print("df1 (CIS62.20250516213458.csv) HEAD")
print("="*50)
print(df1.head(), "\n")
print("df1 INFO")
print("="*50)
print(df1.info(), "\n\n")
# Out:
# ...
# df1 (CIS62.20250516213458.csv) HEAD
# ...
#                                      STATISTIC Label  TLIST(A1)  Year  \
# 0  Enterprises Engaged in Intellectual Property R...       2014  2014
# 1  Enterprises Engaged in Intellectual Property R...       2014  2014
# 2  Enterprises Engaged in Intellectual Property R...       2014  2014
# 3  Enterprises Engaged in Intellectual Property R...       2014  2014
# 4  Enterprises Engaged in Intellectual Property R...       2014  2014
#
#             Type of Innovation  VALUE
# 0  Any intellectual innovation    NaN
# 1  Any intellectual innovation    NaN
# 2  Any intellectual innovation    NaN
# 3           Apply for a patent    NaN
# 4           Apply for a patent    NaN
#
# df1 INFO
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   STATISTIC Label     105 non-null    object
# ...

# %%
# Display head and info for df2
print("="*50)
print("df2 (BSA02.20250516T100541.csv) HEAD")
print("="*50)
print(df2.head(), "\n")
print("df2 INFO")
print("="*50)
print(df2.info(), "\n\n")
# Out:
# ...
# df2 (BSA02.20250516T100541.csv) HEAD
# ...
#                                 Statistic Label  Year  \
# 0  Estimated Current Expenditure - Labour Costs  2007
# 1  Estimated Current Expenditure - Labour Costs  2007
# 2  Estimated Current Expenditure - Labour Costs  2007
# 3  Estimated Current Expenditure - Labour Costs  2008
# 4  Estimated Current Expenditure - Labour Costs  2008
#
#          Nationality of Ownership     VALUE
# 0  All nationalities of ownership       NaN
# 1                 Irish ownership       NaN
# 2             Non Irish ownership       NaN
# 3  All nationalities of ownership  905373.0
# 4                 Irish ownership  308698.0
#
# df2 INFO
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Statistic Label           1080 non-null   object
# ...

# %%
# Display head and info for df3
print("="*50)
print("df3 (BSA22.20250516T200531.csv) HEAD")
print("="*50)
print(df3.head(), "\n")
print("df3 INFO")
print("="*50)
print(df3.info())
# Out:
# ...
# df3 (BSA22.20250516T200531.csv) HEAD
# ...
#                                      Statistic Label  Year  \
# 0  Enterprises Engaged in Research and Developmen...  2007
# 1  Enterprises Engaged in Research and Developmen...  2007
# 2  Enterprises Engaged in Research and Developmen...  2007
# 3  Enterprises Engaged in Research and Developmen...  2007
# 4  Enterprises Engaged in Research and Developmen...  2007
#
#          Nationality of Ownership              Expenditure   VALUE
# 0  All nationalities of ownership          Any expenditure  1206.0
# 1  All nationalities of ownership             €0 - €99,999   419.0
# 2  All nationalities of ownership      €100,000 - €499,999   398.0
# 3  All nationalities of ownership    €500,000 - €1,999,999   226.0
# 4  All nationalities of ownership  €2,000,000 - €4,999,999    90.0
#
# df3 INFO
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 5 columns):
# ...

# %%
import pandas as pd

# Standardize column names
df1.columns = df1.columns.str.strip().str.replace(" ", "_").str.lower()

# Map each IP activity to a code (interpretable)
ip_activity_map = {
    "Any intellectual innovation": 0,
    "Apply for a patent": 1,
    "Apply for a European utility model": 2,
    "Register an industrial design right": 3,
    "Register a trademark": 4,
    "All enterprises using trade secrets": 5,
    "All enterprises claiming copyright": 6
}
df1['ip_activity_code'] = df1['type_of_innovation'].map(ip_activity_map)

# Fill missing VALUE with 0
df1['engagement_rate_pct'] = df1['value'].fillna(0)

# Keep only relevant columns
df1_clean = df1[['year', 'ip_activity_code', 'engagement_rate_pct']]

# %%
# Standardize column names
df2.columns = df2.columns.str.strip().str.replace(" ", "_").str.lower()

# Map Statistic Label to codes (by type of expenditure)
stat_label_map = {
    "Estimated Current Expenditure - Labour Costs": 0,
    "Estimated Current Expenditure - Other Current Costs": 1,
    "Estimated Total Current Expenditure": 2,
    "Estimated Capital Expenditure - Land and Buildings": 3,
    "Estimated Capital Expenditure- Payments made for licences to use intellectual products": 4,
    "Estimated Capital Expenditure - Instruments and Equipment (excluding software)": 5,
    "Estimated Capital Expenditure - Software purchased wholly for Research and Development purposes": 6,
    "Estimated Capital Expenditure - Software development by company in-house and used in-house": 7,
    "Estimated Total Capital Expenditure": 8,
    "Estimated Total Research and Development Expenditure": 9,
    "Actual Current Expenditure - Labour Costs": 10,
    "Actual Current Expenditure - Other Current Costs": 11,
    "Actual Total Current Expenditure": 12,
    "Actual Capital Expenditure - Land and Buildings": 13,
    "Actual Capital Expenditure- Payments made for licences to use intellectual products": 14,
    "Actual Capital Expenditure - Instruments and Equipment (excluding software)": 15,
    "Actual Capital Expenditure - Software purchased wholly for Research and Development purposes": 16,
    "Actual Capital Expenditure - Software development by company in-house and used in-house": 17,
    "Actual Total Capital Expenditure": 18,
    "Actual Total Research and Development Expenditure": 19
}
df2['stat_label_code'] = df2['statistic_label'].map(stat_label_map)

# Map Nationality of Ownership
ownership_map = {
    "Non Irish ownership": 0,
    "Irish ownership": 1,
    "All nationalities of ownership": 2
}
df2['ownership_code'] = df2['nationality_of_ownership'].map(ownership_map)

# Impute missing VALUE with mean per group
df2['expenditure_eur'] = df2.groupby(['stat_label_code', 'ownership_code'])['value'].transform(lambda x: x.fillna(x.mean()))

# Keep only relevant columns
df2_clean = df2[['year', 'stat_label_code', 'ownership_code', 'expenditure_eur']]

# %%
# Standardize column names
df3.columns = df3.columns.str.strip().str.replace(" ", "_").str.lower()

# Map Statistic Label
stat_label_map_df3 = {name: idx for idx, name in enumerate(df3['statistic_label'].unique())}
df3['stat_label_code'] = df3['statistic_label'].map(stat_label_map_df3)

# Map Expenditure
exp_map = {name: idx for idx, name in enumerate(df3['expenditure'].unique())}
df3['expenditure_code'] = df3['expenditure'].map(exp_map)

# Map Nationality of Ownership (reuse ownership_map)
df3['ownership_code'] = df3['nationality_of_ownership'].map(ownership_map)

# Impute missing VALUE
is_count = df3['statistic_label'].str.contains('Number', case=False, na=False)
df3.loc[is_count, 'value'] = df3.loc[is_count, 'value'].fillna(0)
df3['metric_value'] = df3.groupby(['stat_label_code', 'expenditure_code', 'ownership_code'])['value'].transform(lambda x: x.fillna(x.mean()))

# Keep only relevant columns
df3_clean = df3[['year', 'stat_label_code', 'expenditure_code', 'ownership_code', 'metric_value']]

# %%
import pandas as pd

# Merge df1 and df2 on year (outer to preserve all info)
df_merged = pd.merge(df1_clean, df2_clean, on='year', how='outer')

# Merge with df3 on year, stat_label_code, ownership_code, and expenditure_code if present
merge_cols = ['year']
if 'stat_label_code' in df_merged.columns and 'stat_label_code' in df3_clean.columns:
    merge_cols.append('stat_label_code')
if 'ownership_code' in df_merged.columns and 'ownership_code' in df3_clean.columns:
    merge_cols.append('ownership_code')
if 'expenditure_code' in df3_clean.columns and 'expenditure_code' in df_merged.columns:
    merge_cols.append('expenditure_code')

df_merged = pd.merge(df_merged, df3_clean, on=merge_cols, how='outer')

print("Merged DataFrame shape:", df_merged.shape)
print(df_merged.head())
# Out:
# Merged DataFrame shape: (7350, 8)
#    year  ip_activity_code  engagement_rate_pct  stat_label_code  \
# 0  2007               NaN                  NaN                0
# 1  2007               NaN                  NaN                0
# 2  2007               NaN                  NaN                0
# 3  2007               NaN                  NaN                0
# 4  2007               NaN                  NaN                0
#
#    ownership_code  expenditure_eur  expenditure_code  metric_value
# 0               0         845835.0               0.0         389.0
# 1               0         845835.0               1.0          91.0
# 2               0         845835.0               2.0         105.0
# 3               0         845835.0               3.0          79.0
# 4               0         845835.0               4.0          54.0

# %%
import pandas as pd
import numpy as np

# 1. Check missing values per column
print("Missing values per column:\n", df_merged.isnull().sum())

# 2. Drop rows where ALL main value columns are missing (i.e., not a real observation)
value_cols = ['engagement_rate_pct', 'expenditure_eur', 'metric_value']
df_cleaned = df_merged.dropna(subset=value_cols, how='all').copy()

# 3. For each value column, fill missing with 0 if it makes sense (e.g., engagement_rate_pct),
# or with the median/mean of the group if it's an expenditure or metric value.
if 'engagement_rate_pct' in df_cleaned.columns:
    df_cleaned['engagement_rate_pct'] = df_cleaned['engagement_rate_pct'].fillna(0)

if 'expenditure_eur' in df_cleaned.columns:
    df_cleaned['expenditure_eur'] = df_cleaned.groupby(['stat_label_code', 'ownership_code'])['expenditure_eur'].transform(lambda x: x.fillna(x.mean()))

if 'metric_value' in df_cleaned.columns:
    df_cleaned['metric_value'] = df_cleaned.groupby(['stat_label_code', 'expenditure_code', 'ownership_code'])['metric_value'].transform(lambda x: x.fillna(x.mean()))

# 4. For code columns, fill missing with a placeholder (e.g., -1) or the most frequent value if appropriate
code_cols = ['ip_activity_code', 'stat_label_code', 'ownership_code', 'expenditure_code']
for col in code_cols:
    if col in df_cleaned.columns:
        df_cleaned[col] = df_cleaned[col].fillna(-1).astype(int)

# 5. Final check
print("After cleaning, missing values per column:\n", df_cleaned.isnull().sum())
print("Sample cleaned DataFrame:\n", df_cleaned.head())
# Out:
# Missing values per column:
#  year                      0
# ip_activity_code       1050
# engagement_rate_pct    1050
# stat_label_code           0
# ownership_code            0
# expenditure_eur           0
# expenditure_code       7026
# metric_value           7026
# dtype: int64
# After cleaning, missing values per column:
#  year                      0
# ip_activity_code          0
# engagement_rate_pct       0
# stat_label_code           0
# ownership_code            0
# expenditure_eur           0
# expenditure_code          0
# metric_value           7026
# dtype: int64
# Sample cleaned DataFrame:
#     year  ip_activity_code  engagement_rate_pct  stat_label_code  \
# 0  2007                -1                  0.0                0
# 1  2007                -1                  0.0                0
# 2  2007                -1                  0.0                0
# 3  2007                -1                  0.0                0
# ...

# %%
df_cleaned['metric_value'] = df_cleaned['metric_value'].fillna(0)
df_cleaned['metric_value'] = df_cleaned.groupby(
    ['stat_label_code', 'expenditure_code', 'ownership_code']
)['metric_value'].transform(lambda x: x.fillna(x.mean()))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# 1. Overview
print("="*60)
print("DATASET OVERVIEW")
print("="*60)
print(f"\nShape: {df_cleaned.shape}")
print("\nColumns:", df_cleaned.columns.tolist())
print("\nSummary statistics:\n", df_cleaned.describe().transpose())
print("="*60)

# 2. Univariate distributions: Key features
features = ['engagement_rate_pct', 'expenditure_eur', 'metric_value']
plt.figure(figsize=(14, 4))
for i, col in enumerate(features, 1):
    plt.subplot(1, 3, i)
    sns.histplot(df_cleaned[col], bins=20, color=sns.color_palette("bright")[i], edgecolor='black')
    plt.title(f"Distribution of {col}", fontsize=13)
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.grid(alpha=0.3)
plt.tight_layout(pad=3.0)
plt.suptitle("Histograms of Key Numeric Features", fontsize=16, color='darkred', y=1.05)
plt.show()

# 3. Time trends for each main metric
plt.figure(figsize=(12, 6))
for i, col in enumerate(features, 1):
    plt.plot(df_cleaned['year'], df_cleaned[col], marker='o', linestyle='-', label=col)
plt.xlabel("Year")
plt.ylabel("Value")
plt.title("Key Metrics Over Time")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# 4. Correlation heatmap
plt.figure(figsize=(10, 8))
corr = df_cleaned[features + ['ip_activity_code', 'stat_label_code', 'ownership_code', 'expenditure_code']].corr()
sns.heatmap(corr, annot=True, cmap='Spectral', center=0)
plt.title('Correlation Heatmap of Numeric Features', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# ...
# DATASET OVERVIEW
# ...
#
# Shape: (7350, 8)
#
# Columns: ['year', 'ip_activity_code', 'engagement_rate_pct', 'stat_label_code', 'ownership_code', 'expenditure_eur', 'expenditure_code', 'metric_value']
#
# Summary statistics:
#                        count           mean            std     min  \
# year                 7350.0    2017.522449       3.533827  2007.0
# ip_activity_code     7350.0       2.428571       2.321312    -1.0
# engagement_rate_pct  7350.0       3.464490       4.414924     0.0
# stat_label_code      7350.0       9.169388       5.908359     0.0
# ownership_code       7350.0       1.000000       0.816552     0.0
# expenditure_eur      7350.0  588148.967626  906337.138373   246.0
# expenditure_code     7350.0      -0.845714       0.803029    -1.0
# metric_value         7350.0       9.342229      90.937906     0.0
#
#                               25%        50%       75%        max
# year                  2015.000000    2018.00    2020.0     2024.0
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        End Year Type of Innovation  engagement_rate_pct  \
# 0          2007                NaN                  NaN
# 1          2007                NaN                  NaN
# 2          2007                NaN                  NaN
# 3          2007                NaN                  NaN
# 4          2007                NaN                  NaN
# ...         ...                ...                  ...
# 25975      2024                NaN                  NaN
# 25976      2024                NaN                  NaN
# 25977      2024                NaN                  NaN
# 25978      2024                NaN                  NaN
# 25979      2024                NaN                  NaN
#
#        Type_of_Innovation_code  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 25975                      NaN
# ...

# %%
import numpy as np

# 1. Drop rows where all main value columns are missing
value_cols = ['engagement_rate_pct', 'expenditure_eur', 'metric_value']
df_cleaned = df.dropna(subset=value_cols, how='all').copy()

# 2. Fill numeric value columns
if 'engagement_rate_pct' in df_cleaned.columns:
    df_cleaned['engagement_rate_pct'] = df_cleaned['engagement_rate_pct'].fillna(0)
if 'expenditure_eur' in df_cleaned.columns:
    df_cleaned['expenditure_eur'] = df_cleaned['expenditure_eur'].fillna(0)
if 'metric_value' in df_cleaned.columns:
    df_cleaned['metric_value'] = df_cleaned['metric_value'].fillna(0)

# 3. Fill categorical/code columns with -1 or 'Unknown'
cat_cols = [
    'Type of Innovation', 'Type_of_Innovation_code', 'Statistic Label',
    'Statistic_Label_code', 'Nationality of Ownership', 'Nationality_of_Ownership_code',
    'Expenditure', 'Expenditure_code', 'Statistic Label_df3',
    'Statistic_Label_code_df3', 'Nationality of Ownership_df3', 'Nationality_of_Ownership_code_df3'
]
for col in cat_cols:
    if col in df_cleaned.columns:
        if df_cleaned[col].dtype == object:
            df_cleaned[col] = df_cleaned[col].fillna('Unknown')
        else:
            df_cleaned[col] = df_cleaned[col].fillna(-1).astype(int if df_cleaned[col].dtype != float else float)

# 4. Final check
print("Any missing values left?\n", df_cleaned.isnull().sum())
print(df_cleaned.head())
# Out:
# Any missing values left?
#  End Year                             0
# Type of Innovation                   0
# engagement_rate_pct                  0
# Type_of_Innovation_code              0
# Statistic Label                      0
# Nationality of Ownership             0
# expenditure_eur                      0
# Statistic_Label_code                 0
# Nationality_of_Ownership_code        0
# Statistic Label_df3                  0
# Expenditure                          0
# Nationality of Ownership_df3         0
# metric_value                         0
# Statistic_Label_code_df3             0
# Expenditure_code                     0
# Nationality_of_Ownership_code_df3    0
# dtype: int64
#    End Year Type of Innovation  engagement_rate_pct  Type_of_Innovation_code  \
# 0      2007            Unknown                  0.0                     -1.0
# 1      2007            Unknown                  0.0                     -1.0
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

# 1. Check columns and select features
print(df_cleaned.columns.tolist())
features = [
    'engagement_rate_pct', 'expenditure_eur', 'metric_value',
    'Type_of_Innovation_code', 'Statistic_Label_code',
    'Nationality_of_Ownership_code', 'Expenditure_code'
]
features = [col for col in features if col in df_cleaned.columns]

# 2. Prepare data for PCA
X = df_cleaned[features].values

# 3. Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 4. Apply PCA
pca = PCA(n_components=min(len(features), 10))
X_pca = pca.fit_transform(X_scaled)

# 5. Scree plot
plt.figure(figsize=(8, 4))
plt.bar(range(1, len(pca.explained_variance_ratio_)+1), pca.explained_variance_ratio_, color='dodgerblue')
plt.plot(range(1, len(pca.explained_variance_ratio_)+1), np.cumsum(pca.explained_variance_ratio_), marker='o', color='red')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('PCA Scree Plot')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

print("Explained variance by component:", pca.explained_variance_ratio_)
print("Cumulative explained variance:", np.cumsum(pca.explained_variance_ratio_))
# Out:
# ['End Year', 'Type of Innovation', 'engagement_rate_pct', 'Type_of_Innovation_code', 'Statistic Label', 'Nationality of Ownership', 'expenditure_eur', 'Statistic_Label_code', 'Nationality_of_Ownership_code', 'Statistic Label_df3', 'Expenditure', 'Nationality of Ownership_df3', 'metric_value', 'Statistic_Label_code_df3', 'Expenditure_code', 'Nationality_of_Ownership_code_df3']
# Explained variance by component: [0.29451485 0.19611799 0.15211164 0.14285714 0.08959412 0.07959463
#  0.04520962]
# Cumulative explained variance: [0.29451485 0.49063285 0.64274449 0.78560163 0.87519575 0.95479038
#  1.        ]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.scatter(X_pca[:,0], X_pca[:,1], c=df_cleaned['End Year'], cmap='viridis', alpha=0.5)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('PCA: First Two Principal Components')
plt.colorbar(label='End Year')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Use first 3 PCs as features
X_ml = X_pca[:, :3]
# y = your target variable

# %%
pc_df = pd.DataFrame(pca.components_, columns=features, index=[f'PC{i+1}' for i in range(len(features))])
print(pc_df)
# Out:
#      engagement_rate_pct  expenditure_eur  metric_value  \
# PC1         5.414273e-01     1.830051e-02 -1.645533e-01
# PC2        -6.342979e-03     7.068001e-01  1.741005e-02
# PC3        -6.691813e-02    -2.947432e-03  9.149568e-01
# PC4         5.711470e-17     6.658968e-16  1.661949e-16
# PC5         4.450095e-02     7.057244e-01  6.110351e-03
# PC6         8.353227e-01    -4.472602e-02  1.986503e-01
# PC7        -5.092922e-02    -6.535363e-03  3.097966e-01
#
#      Type_of_Innovation_code  Statistic_Label_code  \
# PC1             6.106721e-01              0.005784
# PC2            -1.170276e-02              0.636127
# PC3            -5.128441e-02             -0.015267
# PC4            -6.942923e-17              0.436490
# PC5            -2.035735e-02             -0.635133
# PC6            -3.559380e-01              0.033890
# PC7             7.051286e-01              0.003208
#
#      Nationality_of_Ownership_code  Expenditure_code
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
scatter = plt.scatter(X_pca[:,0], X_pca[:,1], c=df_cleaned['End Year'], cmap='plasma', alpha=0.7)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('PCA: First Two Principal Components')
plt.colorbar(scatter, label='End Year')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# Use first 3 PCs
X_ml = X_pca[:, :3]
y = df_cleaned['metric_value']  # Replace with your actual target

X_train, X_test, y_train, y_test = train_test_split(X_ml, y, test_size=0.2, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
print("R^2 score on test set:", model.score(X_test, y_test))
# Out:
# R^2 score on test set: 0.950422994763974

# %%
from sklearn.model_selection import cross_val_score, KFold

kf = KFold(n_splits=5, shuffle=True, random_state=42)
cv_scores = cross_val_score(model, X_ml, y, cv=kf, scoring='r2')
print(f"Cross-validated R² scores: {cv_scores}")
print(f"Mean R²: {cv_scores.mean():.3f} | Std: {cv_scores.std():.3f}")
# Out:
# Cross-validated R² scores: [0.95042299 0.94425488 0.94877169 0.94572988 0.94838739]
# Mean R²: 0.948 | Std: 0.002

# %%
print("Regression coefficients (for PCs):")
for i, coef in enumerate(model.coef_):
    print(f"PC{i+1}: {coef:.4f}")
# Out:
# Regression coefficients (for PCs):
# PC1: -55.9790
# PC2: 6.0591
# PC3: 312.3437

# %%
pc_df = pd.DataFrame(pca.components_, columns=features, index=[f'PC{i+1}' for i in range(len(features))])
print("\nPrincipal Component Loadings (features most important to each PC):")
print(pc_df.T)
# Out:
# Principal Component Loadings (features most important to each PC):
#                                     PC1       PC2       PC3           PC4  \
# engagement_rate_pct            0.541427 -0.006343 -0.066918  5.711470e-17
# expenditure_eur                0.018301  0.706800 -0.002947  6.658968e-16
# metric_value                  -0.164553  0.017410  0.914957  1.661949e-16
# Type_of_Innovation_code        0.610672 -0.011703 -0.051284 -6.942923e-17
# Statistic_Label_code           0.005784  0.636127 -0.015267  4.364905e-01
# Nationality_of_Ownership_code -0.002806 -0.308615  0.007407  8.997089e-01
# Expenditure_code              -0.553608  0.007288 -0.394271 -1.104030e-16
#
#                                     PC5       PC6       PC7
# engagement_rate_pct            0.044501  0.835323 -0.050929
# expenditure_eur                0.705724 -0.044726 -0.006535
# metric_value                   0.006110  0.198650  0.309797
# Type_of_Innovation_code       -0.020357 -0.355938  0.705129
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
rf_score = rf.score(X_test, y_test)
print(f"Random Forest R² on test set: {rf_score:.3f}")
# Out:
# Random Forest R² on test set: 1.000

# %%
from sklearn.linear_model import Ridge

ridge = Ridge(alpha=1.0)
ridge.fit(X_train, y_train)
ridge_score = ridge.score(X_test, y_test)
print(f"Ridge Regression R² on test set: {ridge_score:.3f}")
# Out:
# Ridge Regression R² on test set: 0.950

# %%
import matplotlib.pyplot as plt

y_pred = model.predict(X_test)
plt.figure(figsize=(8,6))
plt.scatter(y_test, y_pred, alpha=0.6, color='dodgerblue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs. Predicted (Test Set)')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
print("="*60)
print("ML Pipeline Summary")
print("="*60)
print(f"Best Linear Regression R² (test set): {model.score(X_test, y_test):.3f}")
print(f"Cross-validated R² (mean ± std): {cv_scores.mean():.3f} ± {cv_scores.std():.3f}")
print(f"Random Forest R² (test set): {rf_score:.3f}")
print(f"Ridge Regression R² (test set): {ridge_score:.3f}")
print("\nKey findings:")
print("- PCA reduces dimensionality while preserving >95% variance in 5-6 components.")
print("- Linear regression on PCs explains most of the variance in the target.")
print("- Model coefficients and PC loadings help interpret the influence of original features.")
print("- Random Forest and Ridge can confirm or improve performance.")
print("="*60)
# Out:
# ...
# ML Pipeline Summary
# ...
# Best Linear Regression R² (test set): 0.950
# Cross-validated R² (mean ± std): 0.948 ± 0.002
# Random Forest R² (test set): 1.000
# Ridge Regression R² (test set): 0.950
#
# Key findings:
# - PCA reduces dimensionality while preserving >95% variance in 5-6 components.
# - Linear regression on PCs explains most of the variance in the target.
# - Model coefficients and PC loadings help interpret the influence of original features.
# - Random Forest and Ridge can confirm or improve performance.
# ...
